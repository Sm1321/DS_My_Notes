# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
corpus = """ Hello Welcome ,to Google colab'd NLP Tutorials.
Please do watch the entire course ! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
#  Hello Welcome ,to Google colab'd NLP Tutorials.
# Please do watch the entire course ! to become expert in NLP.

# %%
import nltk
nltk.download('punkt')

### Tokenization

## Senetence ---> Paragraphs

# Convert paargraph into sentence
from nltk.tokenize import sent_tokenize


from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
document = sent_tokenize(corpus)

# %%
document
# Out:
# [" Hello Welcome ,to Google colab'd NLP Tutorials.",
#  'Please do watch the entire course !',
#  'to become expert in NLP.']

# %%
type(document)
# Out:
# list

# %%
for sentence in  document:
    print(sentence)
# Out:
#  Hello Welcome ,to Google colab'd NLP Tutorials.
# Please do watch the entire course !
# to become expert in NLP.

# %%
### Tokenization

## Paragraph --> words

### Sentencee --> Words

from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Google',
#  'colab',
#  "'d",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in document:
  print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Google', 'colab', "'d", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# 's -> this will be get splitted
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Google',
#  'colab',
#  "'",
#  'd',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
# Import the tokenizer
from nltk.tokenize import TreebankWordTokenizer

# %%
# Create an instance of the tokenizer
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# only for last word full-stop will be considered as diffrent word
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Google',
#  'colab',
#  "'d",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
