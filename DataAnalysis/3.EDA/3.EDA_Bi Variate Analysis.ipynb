# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_sales = pd.read_csv('Sales_Data.csv')
df_loan = pd.read_csv('Loandata.csv')
df_titanic = pd.read_csv('Titanic.csv')

# %%
### Violin Plot
sns.violinplot(df_loan['LoanAmount'])
# Out:
# <Axes: >

# %%
sns.violinplot(x=df_loan['LoanAmount'])
# Out:
# <Axes: xlabel='LoanAmount'>

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
#### Bivariate analysis

# %%
a = [40,60,30,35,15,36]

# %%
np.cov(a,a)
# Out:
# array([[214., 214.],
#        [214., 214.]])

# %%
b =[15,5,20,25,30,29]
np.cov(b,b)
# Out:
# array([[90.66666667, 90.66666667],
#        [90.66666667, 90.66666667]])

# %%
np.cov(a,b)
# Out:
# array([[ 214.        , -119.        ],
#        [-119.        ,   90.66666667]])

# %%
np.corrcoef(a,b)
# Out:
# array([[ 1.       , -0.8543115],
#        [-0.8543115,  1.       ]])

# %%
np.corrcoef(a,b)[1][0]
# Out:
# -0.8543114952060058

# %%
np.corrcoef(a,b)[0][1]
# Out:
# -0.8543114952060058

# %%
a_std = np.std(a)

# %%
a_std
# Out:
# 13.354150416006753

# %%
b_std = np.std(b)

# %%
b_std
# Out:
# 8.692269873603532

# %%
np.cov(a,b)[1][0]/(a_std*b_std)
# Out:
# -1.025173794247207

# %%
224*224*3*2048
# Out:
# 308281344

# %%
#### SCatter Plot
plt.scatter(df_loan.ApplicantIncome,df_loan.LoanAmount)

# %%
plt.scatter(df_loan.ApplicantIncome,df_loan.LoanAmount)
plt.show()

# %%
plt.scatter(df_loan.ApplicantIncome,df_loan.LoanAmount)
plt.title('ApplicantIncome vs LoanAmount')
plt.ylabel(' Applicant Income')
plt.xlabel('Loan Amount')
plt.show()

# %%
df_loan.ApplicantIncome.corr(df_loan.LoanAmount)
# Out:
# 0.5709090389885669

# %%
df_loan['ApplicantIncome'].corr(df_loan['LoanAmount'])
# Out:
# 0.5709090389885669

# %%
df_loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
### ApplicantIncome w.r.t CoapplicantIncome
### Plot the scatter plot

# %%
plt.scatter(df_loan.ApplicantIncome,df_loan.CoapplicantIncome)
plt.title('ApplicantIncome vs CoapplicantIncome')
plt.ylabel(' Applicant Income')
plt.xlabel('CoapplicantIncome')
plt.show()
df_loan.ApplicantIncome.corr(df_loan.CoapplicantIncome)
# Out:
# -0.11660458122889969

# %%
#### Plot scatter plot for Unit selling price w.r.t Unit making cost in Sales data ?
###  What is your observation here..

# %%
## as making cost increases the price of the product is increases

# %%
plt.scatter(df_sales.Unit_SellingPrice,df_sales.Unit_MakingCost)
plt.title('Unit_SellingPrice vs Unit_MakingCost')
plt.xlabel('Unit_SellingPrice')
plt.ylabel('Unit_MakingCost')
plt.show()

df_sales.Unit_SellingPrice.corr(df_sales.Unit_MakingCost)
# Out:
# 0.9862309527482931

# %%
df_sales
# Out:
#                                  Region               Country   Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
plt.scatter(df_sales.Units_Sold,df_sales.Total_Revenue)
plt.title('Units_Sold vs Total_Revenue')
plt.xlabel('Units_Sold')
plt.ylabel('Total_Revenue')
plt.show()

df_sales.Units_Sold.corr(df_sales.Total_Revenue)
# Out:
# 0.5118208932292375

# %%
plt.scatter(df_sales.Total_Cost,df_sales.Total_Profit)
plt.ylabel('Total_Cost')
plt.xlabel('Total Profit')
plt.show()


df_sales.Total_Cost.corr(df_sales.Total_Profit)
# Out:
# 0.8005062805756789

# %%
plt.scatter(df_sales.Units_Sold,df_sales.Total_Profit)
plt.ylabel('Units Sold')
plt.xlabel('Total Profit')
plt.show()
df_sales.Units_Sold.corr(df_sales.Total_Profit)
# Out:
# 0.5864157928219438

# %%
plt.scatter(df_sales.Unit_MakingCost,df_sales.Total_Revenue)
plt.title('Unit_MakingCost vs Total_Revenue')
df_sales.Unit_MakingCost.corr(df_sales.Total_Revenue)
# Out:
# 0.7226761137756996

# %%
#### Pairplot
sns.pairplot(data=df_sales,vars=['Total_Revenue','Total_Profit','Total_Cost'])
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(data=df_sales,vars=['Total_Revenue','Total_Profit','Sales_Channel'])
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#### Heat map
df_loan[['LoanAmount','ApplicantIncome','CoapplicantIncome']].corr()
# Out:
#                    LoanAmount  ApplicantIncome  CoapplicantIncome
# LoanAmount           1.000000         0.570909           0.188619
# ApplicantIncome      0.570909         1.000000          -0.116605
# CoapplicantIncome    0.188619        -0.116605           1.000000

# %%
sns.heatmap(df_loan[['LoanAmount','ApplicantIncome','CoapplicantIncome']].corr(),annot=False)
plt.show()

# %%
sns.heatmap(df_loan.corr(),annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sns.heatmap(df_loan.corr(),annot=True)
#       2 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
# ...

# %%
sns.heatmap(df_sales.corr(),annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 sns.heatmap(df_sales.corr(),annot=True)
#       2 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
# ...

# %%
df_sales
# Out:
#                                  Region               Country   Item_Type  \
# 0     Central America and the Caribbean  Antigua and Barbuda    Baby Food
# 1     Central America and the Caribbean                Panama      Snacks
# 2                                Europe        Czech Republic   Beverages
# 3                                  Asia           North Korea      Cereal
# 4                                  Asia             Sri Lanka      Snacks
# ...                                 ...                   ...         ...
# 4995              Australia and Oceania           New Zealand   Household
# 4996       Middle East and North Africa            Azerbaijan     Clothes
# 4997                               Asia               Myanmar   Baby Food
# 4998                             Europe               Finland     Clothes
# 4999                 Sub-Saharan Africa              Tanzania  Vegetables
#
#      Sales_Channel Order_Priority  Order_Date     Order_ID   Ship_Date  \
# ...

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Region             5000 non-null   object
#  1   Country            5000 non-null   object
#  2   Item_Type          4989 non-null   object
#  3   Sales_Channel      5000 non-null   object
#  4   Order_Priority     5000 non-null   object
#  5   Order_Date         5000 non-null   object
#  6   Order_ID           4997 non-null   float64
#  7   Ship_Date          5000 non-null   object
#  8   Units_Sold         5000 non-null   int64
#  9   Unit_SellingPrice  5000 non-null   float64
#  10  Unit_MakingCost    5000 non-null   float64
#  11  Total_Revenue      5000 non-null   float64
#  12  Total_Cost         5000 non-null   float64
#  13  Total_Profit       5000 non-null   float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 547.0+ KB

# %%
df_sales.Order_Date
# Out:
# 0       12/20/2013
# 1       07-05-2010
# 2       09-12-2011
# 3        5/13/2010
# 4        7/20/2015
#            ...
# 4995    04-03-2015
# 4996     8/17/2014
# 4997    11/23/2016
# 4998     4/22/2014
# 4999    07-08-2011
# Name: Order_Date, Length: 5000, dtype: object
