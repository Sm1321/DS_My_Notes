# %%
import numpy as np
import pandas as pd

# %%
_dict = {
        'Id' : [0,1,2,3],
        'first_score' : [100.0,'Nan',90.0,95.0],
        'Second_score' : [30.0,45.0,57.0,'Nan'],
        'Third_score': ['Nan',40.0,80.0,98.0]
    
}

# %%
df_New = pd.DataFrame(_dict)

# %%
df_New
# Out:
#    Id first_score Second_score Third_score
# 0   0       100.0         30.0         Nan
# 1   1         Nan         45.0        40.0
# 2   2        90.0         57.0        80.0
# 3   3        95.0          Nan        98.0

# %%
_dict = {
        'Id' : [0,1,2,3],
        'first_score' : [100.0,np.NaN,90.0,95.0],
        'Second_score' : [30.0,45.0,57.0,np.NaN],
        'Third_score': [np.NaN,40.0,80.0,98.0]
    
}

# %%
df_New = pd.DataFrame(_dict)

# %%
df_New
# Out:
#    Id  first_score  Second_score  Third_score
# 0   0        100.0          30.0          NaN
# 1   1          NaN          45.0         40.0
# 2   2         90.0          57.0         80.0
# 3   3         95.0           NaN         98.0

# %%
df=pd.read_csv('loandata.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df_New
# Out:
#    Id  first_score  Second_score  Third_score
# 0   0        100.0          30.0          NaN
# 1   1          NaN          45.0         40.0
# 2   2         90.0          57.0         80.0
# 3   3         95.0           NaN         98.0

# %%
#### Filling Missing values with previous values of the columns---> Forwardfill ffill
df_New.fillna(method='pad')
# Out:
#    Id  first_score  Second_score  Third_score
# 0   0        100.0          30.0          NaN
# 1   1        100.0          45.0         40.0
# 2   2         90.0          57.0         80.0
# 3   3         95.0          57.0         98.0

# %%
df_New
# Out:
#    Id  first_score  Second_score  Third_score
# 0   0        100.0          30.0          NaN
# 1   1          NaN          45.0         40.0
# 2   2         90.0          57.0         80.0
# 3   3         95.0           NaN         98.0

# %%
##### Backward Fill
df_New.fillna(method='bfill')
# Out:
#    Id  first_score  Second_score  Third_score
# 0   0        100.0          30.0         40.0
# 1   1         90.0          45.0         40.0
# 2   2         90.0          57.0         80.0
# 3   3         95.0           NaN         98.0

# %%
### fill with constant
df_New.fillna(value=50)
# Out:
#    Id  first_score  Second_score  Third_score
# 0   0        100.0          30.0         50.0
# 1   1         50.0          45.0         40.0
# 2   2         90.0          57.0         80.0
# 3   3         95.0          50.0         98.0

# %%
df1 = pd.read_csv('missing.csv')

# %%
df1
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0         NaN           Y
# 1   LP001003    NaN     Yes        NaN      2000.0           N
# 2   LP001005   Male     N/a        NaN       500.0           Y
# 3   LP001006    NaN     NaN        NaN       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5        NaN    NaN     NaN        NaN         NaN           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018      -     Yes          2       800.0           Y
# 9        NaN    NaN     NaN        NaN         NaN         NaN
# 10  LP001014   Male       -         3+      1000.0         NaN

# %%
df1.Gender.unique()
# Out:
# array(['Male', nan, '-'], dtype=object)

# %%
df1.isnull().sum()
# Out:
# Loan_ID        2
# Gender         4
# Married        3
# Dependents     5
# Income         3
# Loan_Status    2
# dtype: int64

# %%
list1 =['N/a','-','na']

# %%
df1=pd.read_csv('missing.csv',na_values=list1)

# %%
df1
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0         NaN           Y
# 1   LP001003    NaN     Yes        NaN      2000.0           N
# 2   LP001005   Male     NaN        NaN       500.0           Y
# 3   LP001006    NaN     NaN        NaN       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5        NaN    NaN     NaN        NaN         NaN           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018    NaN     Yes          2       800.0           Y
# 9        NaN    NaN     NaN        NaN         NaN         NaN
# 10  LP001014   Male     NaN         3+      1000.0         NaN

# %%
df1.isnull().sum()
# Out:
# Loan_ID        2
# Gender         5
# Married        5
# Dependents     5
# Income         3
# Loan_Status    2
# dtype: int64

# %%
df1.isnull().sum()/len(df1)*100
# Out:
# Loan_ID        18.181818
# Gender         45.454545
# Married        45.454545
# Dependents     45.454545
# Income         27.272727
# Loan_Status    18.181818
# dtype: float64

# %%
#### Locate the rows with gender having nan

# %%
df1.loc[df1.Gender.isna()]
# Out:
#     Loan_ID Gender Married Dependents  Income Loan_Status
# 1  LP001003    NaN     Yes        NaN  2000.0           N
# 3  LP001006    NaN     NaN        NaN   300.0           Y
# 5       NaN    NaN     NaN        NaN     NaN           Y
# 8  LP001018    NaN     Yes          2   800.0           Y
# 9       NaN    NaN     NaN        NaN     NaN         NaN

# %%
df1[df1.Gender.isnull()]
# Out:
#     Loan_ID Gender Married Dependents  Income Loan_Status
# 1  LP001003    NaN     Yes        NaN  2000.0           N
# 3  LP001006    NaN     NaN        NaN   300.0           Y
# 5       NaN    NaN     NaN        NaN     NaN           Y
# 8  LP001018    NaN     Yes          2   800.0           Y
# 9       NaN    NaN     NaN        NaN     NaN         NaN

# %%
df1.loc[df1.Gender.isnull()]
# Out:
#     Loan_ID Gender Married Dependents  Income Loan_Status
# 1  LP001003    NaN     Yes        NaN  2000.0           N
# 3  LP001006    NaN     NaN        NaN   300.0           Y
# 5       NaN    NaN     NaN        NaN     NaN           Y
# 8  LP001018    NaN     Yes          2   800.0           Y
# 9       NaN    NaN     NaN        NaN     NaN         NaN

# %%
### All Nan should fill with 89
df1.fillna(value = 89)
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0        89.0           Y
# 1   LP001003     89     Yes         89      2000.0           N
# 2   LP001005   Male      89         89       500.0           Y
# 3   LP001006     89      89         89       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5         89     89      89         89        89.0           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018     89     Yes          2       800.0           Y
# 9         89     89      89         89        89.0          89
# 10  LP001014   Male      89         3+      1000.0          89

# %%
### backward fill
df1.fillna(method = 'bfill')
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0      2000.0           Y
# 1   LP001003   Male     Yes          0      2000.0           N
# 2   LP001005   Male      No          0       500.0           Y
# 3   LP001006   Male      No          0       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5   LP001013   Male     Yes          0       600.0           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018   Male     Yes          2       800.0           Y
# 9   LP001014   Male     NaN         3+      1000.0         NaN
# 10  LP001014   Male     NaN         3+      1000.0         NaN

# %%
### forward fill 
df1.fillna(method = 'pad')
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0         NaN           Y
# 1   LP001003   Male     Yes          0      2000.0           N
# 2   LP001005   Male     Yes          0       500.0           Y
# 3   LP001006   Male     Yes          0       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5   LP001008   Male      No          0       500.0           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018   Male     Yes          2       800.0           Y
# 9   LP001018   Male     Yes          2       800.0           Y
# 10  LP001014   Male     Yes         3+      1000.0           Y

# %%
df1
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0         NaN           Y
# 1   LP001003    NaN     Yes        NaN      2000.0           N
# 2   LP001005   Male     NaN        NaN       500.0           Y
# 3   LP001006    NaN     NaN        NaN       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5        NaN    NaN     NaN        NaN         NaN           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018    NaN     Yes          2       800.0           Y
# 9        NaN    NaN     NaN        NaN         NaN         NaN
# 10  LP001014   Male     NaN         3+      1000.0         NaN

# %%
df1.dropna(how='any')
# Out:
#     Loan_ID Gender Married Dependents      Income Loan_Status
# 4  LP001008   Male      No          0       500.0           N
# 6  LP001013   Male     Yes          0       600.0           Y
# 7  LP001013   Male     Yes          0  60000000.0           Y

# %%
df1
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0         NaN           Y
# 1   LP001003    NaN     Yes        NaN      2000.0           N
# 2   LP001005   Male     NaN        NaN       500.0           Y
# 3   LP001006    NaN     NaN        NaN       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5        NaN    NaN     NaN        NaN         NaN           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018    NaN     Yes          2       800.0           Y
# 9        NaN    NaN     NaN        NaN         NaN         NaN
# 10  LP001014   Male     NaN         3+      1000.0         NaN

# %%
df1.dropna(how='all')
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0         NaN           Y
# 1   LP001003    NaN     Yes        NaN      2000.0           N
# 2   LP001005   Male     NaN        NaN       500.0           Y
# 3   LP001006    NaN     NaN        NaN       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5        NaN    NaN     NaN        NaN         NaN           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018    NaN     Yes          2       800.0           Y
# 10  LP001014   Male     NaN         3+      1000.0         NaN

# %%
df1.dropna(how = 'any', subset = ['Income','Loan_Status'])
# Out:
#     Loan_ID Gender Married Dependents      Income Loan_Status
# 1  LP001003    NaN     Yes        NaN      2000.0           N
# 2  LP001005   Male     NaN        NaN       500.0           Y
# 3  LP001006    NaN     NaN        NaN       300.0           Y
# 4  LP001008   Male      No          0       500.0           N
# 6  LP001013   Male     Yes          0       600.0           Y
# 7  LP001013   Male     Yes          0  60000000.0           Y
# 8  LP001018    NaN     Yes          2       800.0           Y

# %%
df1
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0         NaN           Y
# 1   LP001003    NaN     Yes        NaN      2000.0           N
# 2   LP001005   Male     NaN        NaN       500.0           Y
# 3   LP001006    NaN     NaN        NaN       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5        NaN    NaN     NaN        NaN         NaN           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018    NaN     Yes          2       800.0           Y
# 9        NaN    NaN     NaN        NaN         NaN         NaN
# 10  LP001014   Male     NaN         3+      1000.0         NaN

# %%
df1[df1.Loan_Status.notnull()]
# Out:
#     Loan_ID Gender Married Dependents      Income Loan_Status
# 0  LP001002   Male      No          0         NaN           Y
# 1  LP001003    NaN     Yes        NaN      2000.0           N
# 2  LP001005   Male     NaN        NaN       500.0           Y
# 3  LP001006    NaN     NaN        NaN       300.0           Y
# 4  LP001008   Male      No          0       500.0           N
# 5       NaN    NaN     NaN        NaN         NaN           Y
# 6  LP001013   Male     Yes          0       600.0           Y
# 7  LP001013   Male     Yes          0  60000000.0           Y
# 8  LP001018    NaN     Yes          2       800.0           Y

# %%
df1[df1.Loan_Status.notna()]
# Out:
#     Loan_ID Gender Married Dependents      Income Loan_Status
# 0  LP001002   Male      No          0         NaN           Y
# 1  LP001003    NaN     Yes        NaN      2000.0           N
# 2  LP001005   Male     NaN        NaN       500.0           Y
# 3  LP001006    NaN     NaN        NaN       300.0           Y
# 4  LP001008   Male      No          0       500.0           N
# 5       NaN    NaN     NaN        NaN         NaN           Y
# 6  LP001013   Male     Yes          0       600.0           Y
# 7  LP001013   Male     Yes          0  60000000.0           Y
# 8  LP001018    NaN     Yes          2       800.0           Y

# %%
df1.dropna(how = 'any',subset=['Loan_Status'])
# Out:
#     Loan_ID Gender Married Dependents      Income Loan_Status
# 0  LP001002   Male      No          0         NaN           Y
# 1  LP001003    NaN     Yes        NaN      2000.0           N
# 2  LP001005   Male     NaN        NaN       500.0           Y
# 3  LP001006    NaN     NaN        NaN       300.0           Y
# 4  LP001008   Male      No          0       500.0           N
# 5       NaN    NaN     NaN        NaN         NaN           Y
# 6  LP001013   Male     Yes          0       600.0           Y
# 7  LP001013   Male     Yes          0  60000000.0           Y
# 8  LP001018    NaN     Yes          2       800.0           Y

# %%
df1
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0         NaN           Y
# 1   LP001003    NaN     Yes        NaN      2000.0           N
# 2   LP001005   Male     NaN        NaN       500.0           Y
# 3   LP001006    NaN     NaN        NaN       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5        NaN    NaN     NaN        NaN         NaN           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018    NaN     Yes          2       800.0           Y
# 9        NaN    NaN     NaN        NaN         NaN         NaN
# 10  LP001014   Male     NaN         3+      1000.0         NaN

# %%
x = df1.Income.mean()

df1.fillna(value= x)
# Out:
#       Loan_ID     Gender    Married Dependents      Income Loan_Status
# 0    LP001002       Male         No          0   7500712.5           Y
# 1    LP001003  7500712.5        Yes  7500712.5      2000.0           N
# 2    LP001005       Male  7500712.5  7500712.5       500.0           Y
# 3    LP001006  7500712.5  7500712.5  7500712.5       300.0           Y
# 4    LP001008       Male         No          0       500.0           N
# 5   7500712.5  7500712.5  7500712.5  7500712.5   7500712.5           Y
# 6    LP001013       Male        Yes          0       600.0           Y
# 7    LP001013       Male        Yes          0  60000000.0           Y
# 8    LP001018  7500712.5        Yes          2       800.0           Y
# 9   7500712.5  7500712.5  7500712.5  7500712.5   7500712.5   7500712.5
# 10   LP001014       Male  7500712.5         3+      1000.0   7500712.5

# %%
mean_income = df1['Income'].mean()

#mean_income

df1['Income'].fillna(mean_income)
# Out:
# 0      7500712.5
# 1         2000.0
# 2          500.0
# 3          300.0
# 4          500.0
# 5      7500712.5
# 6          600.0
# 7     60000000.0
# 8          800.0
# 9      7500712.5
# 10        1000.0
# Name: Income, dtype: float64

# %%
df1['Income'].fillna(df1['Income'].mean())
# Out:
# 0      7500712.5
# 1         2000.0
# 2          500.0
# 3          300.0
# 4          500.0
# 5      7500712.5
# 6          600.0
# 7     60000000.0
# 8          800.0
# 9      7500712.5
# 10        1000.0
# Name: Income, dtype: float64

# %%
df1
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status
# 0   LP001002   Male      No          0         NaN           Y
# 1   LP001003    NaN     Yes        NaN      2000.0           N
# 2   LP001005   Male     NaN        NaN       500.0           Y
# 3   LP001006    NaN     NaN        NaN       300.0           Y
# 4   LP001008   Male      No          0       500.0           N
# 5        NaN    NaN     NaN        NaN         NaN           Y
# 6   LP001013   Male     Yes          0       600.0           Y
# 7   LP001013   Male     Yes          0  60000000.0           Y
# 8   LP001018    NaN     Yes          2       800.0           Y
# 9        NaN    NaN     NaN        NaN         NaN         NaN
# 10  LP001014   Male     NaN         3+      1000.0         NaN

# %%
df1['del']=df1['Income'].replace(np.nan,99999)

# %%
df1
# Out:
#      Loan_ID Gender Married Dependents      Income Loan_Status     Income1  \
# 0   LP001002   Male      No          0         NaN           Y   7500712.5
# 1   LP001003    NaN     Yes        NaN      2000.0           N      2000.0
# 2   LP001005   Male     NaN        NaN       500.0           Y       500.0
# 3   LP001006    NaN     NaN        NaN       300.0           Y       300.0
# 4   LP001008   Male      No          0       500.0           N       500.0
# 5        NaN    NaN     NaN        NaN         NaN           Y   7500712.5
# 6   LP001013   Male     Yes          0       600.0           Y       600.0
# 7   LP001013   Male     Yes          0  60000000.0           Y  60000000.0
# 8   LP001018    NaN     Yes          2       800.0           Y       800.0
# 9        NaN    NaN     NaN        NaN         NaN         NaN   7500712.5
# 10  LP001014   Male     NaN         3+      1000.0         NaN      1000.0
#
#        Income2         del
# 0    7500712.5     99999.0
# ...
