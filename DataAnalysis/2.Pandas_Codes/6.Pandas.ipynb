# %%
import pandas as pd
import numpy as np

d1 = {
    'Name':['Tom','Andy','Lusi'],
    'DoB':['08-05-1997','04-09-1996','12/16/1995']
}
df = pd.DataFrame(d1)

# %%
df
# Out:
#    Name         DoB
# 0   Tom  08-05-1997
# 1  Andy  04-09-1996
# 2  Lusi  12/16/1995

# %%
#### pandas datae range
pd.date_range('2024/03/18',periods=10)
# Out:
# DatetimeIndex(['2024-03-18', '2024-03-19', '2024-03-20', '2024-03-21',
#                '2024-03-22', '2024-03-23', '2024-03-24', '2024-03-25',
#                '2024-03-26', '2024-03-27'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2024/03/18',periods=15)
# Out:
# DatetimeIndex(['2024-03-18', '2024-03-19', '2024-03-20', '2024-03-21',
#                '2024-03-22', '2024-03-23', '2024-03-24', '2024-03-25',
#                '2024-03-26', '2024-03-27', '2024-03-28', '2024-03-29',
#                '2024-03-30', '2024-03-31', '2024-04-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
start = pd.datetime(2024,3,18)
print('Start :',start)

end = pd.datetime(2024,3,31)
print('Stop: ',end)
# Out:
# Start : 2024-03-18 00:00:00
# Stop:  2024-03-31 00:00:00
# C:\Users\pc\AppData\Local\Temp\ipykernel_26168\1898083868.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   start = pd.datetime(2024,3,18)
# C:\Users\pc\AppData\Local\Temp\ipykernel_26168\1898083868.py:4: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   end = pd.datetime(2024,3,31)

# %%
pd.date_range(start,end)
# Out:
# DatetimeIndex(['2024-03-18', '2024-03-19', '2024-03-20', '2024-03-21',
#                '2024-03-22', '2024-03-23', '2024-03-24', '2024-03-25',
#                '2024-03-26', '2024-03-27', '2024-03-28', '2024-03-29',
#                '2024-03-30', '2024-03-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
#### Month wise 
pd.date_range('2024/3/18',periods=6,freq='Y')
# Out:
# DatetimeIndex(['2024-12-31', '2025-12-31', '2026-12-31', '2027-12-31',
#                '2028-12-31', '2029-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
df
# Out:
#    Name         DoB
# 0   Tom  08-05-1997
# 1  Andy  04-09-1996
# 2  Lusi  12/16/1995

# %%
df['DoB'] = pd.to_datetime(df['DoB'])

# %%
df
# Out:
#    Name        DoB
# 0   Tom 1997-08-05
# 1  Andy 1996-04-09
# 2  Lusi 1995-12-16

# %%
df['DoB']
# Out:
# 0   1997-08-05
# 1   1996-04-09
# 2   1995-12-16
# Name: DoB, dtype: datetime64[ns]

# %%
df['DoB'].dt.year
# Out:
# 0    1997
# 1    1996
# 2    1995
# Name: DoB, dtype: int64

# %%
today = pd.to_datetime('today')

# %%
today
# Out:
# Timestamp('2024-03-18 07:56:46.914649')

# %%
today.year
# Out:
# 2024

# %%
today.month
# Out:
# 3

# %%
today.date
# Out:
# <function Timestamp.date>

# %%
today.day
# Out:
# 18

# %%
today.year-df['DoB'].dt.year
# Out:
# 0    27
# 1    28
# 2    29
# Name: DoB, dtype: int64

# %%
df
# Out:
#    Name        DoB
# 0   Tom 1997-08-05
# 1  Andy 1996-04-09
# 2  Lusi 1995-12-16

# %%
df['Age']=today.year-df['DoB'].dt.year

# %%
df
# Out:
#    Name        DoB  Age
# 0   Tom 1997-08-05   27
# 1  Andy 1996-04-09   28
# 2  Lusi 1995-12-16   29

# %%
df['DoB'].dt.year
# Out:
# 0    1997
# 1    1996
# 2    1995
# Name: DoB, dtype: int64

# %%
df['DoB'].dt.month
# Out:
# 0     8
# 1     4
# 2    12
# Name: DoB, dtype: int64

# %%
df['DoB'].dt.day
# Out:
# 0     5
# 1     9
# 2    16
# Name: DoB, dtype: int64

# %%
df['DoB'].dt.week
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_26168\609773194.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['DoB'].dt.week
# 0    32
# 1    15
# 2    50
# Name: DoB, dtype: int64

# %%
df['DoB'].dt.day_name()
# Out:
# 0     Tuesday
# 1     Tuesday
# 2    Saturday
# Name: DoB, dtype: object

# %%
df['Day'] = df['DoB'].dt.day_name()

# %%
df
# Out:
#    Name        DoB  Age       Day
# 0   Tom 1997-08-05   27   Tuesday
# 1  Andy 1996-04-09   28   Tuesday
# 2  Lusi 1995-12-16   29  Saturday

# %%
today.day_name()
# Out:
# 'Monday'

# %%
s1 = pd.Series([110,120,130,140,150])
s2 = pd.Series(['Ram','Jack','Pot','Rock','Alen'])
df1 = pd.DataFrame({'ID':s1,'Name':s2})

# %%
df1
# Out:
#     ID  Name
# 0  110   Ram
# 1  120  Jack
# 2  130   Pot
# 3  140  Rock
# 4  150  Alen

# %%
df1['Salary']=['40k','50k','60k','70k','80k']

# %%
df1
# Out:
#     ID  Name Salary
# 0  110   Ram    40k
# 1  120  Jack    50k
# 2  130   Pot    60k
# 3  140  Rock    70k
# 4  150  Alen    80k

# %%
_dic = {
    
        'Gender': ['Male','Female','Male','Female','Male'],
        'Married': ['Yes','No','No','No','Yes'],
        'Loan-Status': ['Yes','No','No','No','Yes']
}
df = pd.DataFrame(_dic)

# %%
df
# Out:
#    Gender Married Loan-Status
# 0    Male     Yes         Yes
# 1  Female      No          No
# 2    Male      No          No
# 3  Female      No          No
# 4    Male     Yes         Yes

# %%
duplicates_first = df.duplicated(keep ='first')
duplicates_first
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
df.loc[duplicates_first,:]
# Out:
#    Gender Married Loan-Status
# 3  Female      No          No
# 4    Male     Yes         Yes

# %%
duplicates_last = df.duplicated(keep ='last')
duplicates_last
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.loc[duplicates_last,:]
# Out:
#    Gender Married Loan-Status
# 0    Male     Yes         Yes
# 1  Female      No          No

# %%
df1 = df.drop_duplicates(keep='first')

# %%
df1
# Out:
#    Gender Married Loan-Status
# 0    Male     Yes         Yes
# 1  Female      No          No
# 2    Male      No          No

# %%
df1 = df.drop_duplicates(keep='last')

# %%
df1
# Out:
#    Gender Married Loan-Status
# 2    Male      No          No
# 3  Female      No          No
# 4    Male     Yes         Yes

# %%
df = pd.read_csv('Titanic.csv')

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
len(df.Sex.unique())
# Out:
# 2

# %%
df.Sex.nunique()
# Out:
# 2

# %%
df[df.Age>40]
# Out:
#      PassengerId  Pclass                                               Name  \
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 11           903       1                         Jones, Mr. Charles Cresson
# 13           905       2                               Howard, Mr. Benjamin
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# ..           ...     ...                                                ...
# 391         1283       1     Lines, Mrs. Ernest H (Elizabeth Lindsey James)
# 393         1285       2                               Gilbert, Mr. William
# 397         1289       1  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 407         1299       1                         Widener, Mr. George Dunton
#
# ...

# %%
df[(df.Age >= 40) & (df.Age <= 50)]
# Out:
#      PassengerId  Pclass                                               Name  \
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 11           903       1                         Jones, Mr. Charles Cresson
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 19           911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 25           917       3                            Robins, Mr. Alexander A
# 28           920       1                            Brady, Mr. John Bertram
# 30           922       2                       Louch, Mr. Charles Alexander
# 42           934       3                              Goldsmith, Mr. Nathan
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46           938       1                           Chevre, Mr. Paul Romaine
# ...

# %%
df2 =df[df.Age.between(40,50)]

# %%
df2
# Out:
#      PassengerId  Pclass                                               Name  \
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 11           903       1                         Jones, Mr. Charles Cresson
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 19           911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 25           917       3                            Robins, Mr. Alexander A
# 28           920       1                            Brady, Mr. John Bertram
# 30           922       2                       Louch, Mr. Charles Alexander
# 42           934       3                              Goldsmith, Mr. Nathan
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 46           938       1                           Chevre, Mr. Paul Romaine
# ...

# %%
df[df.Age.isin([42,46])]
# Out:
#      PassengerId  Pclass                                               Name  \
# 11           903       1                         Jones, Mr. Charles Cresson
# 128         1020       2                               Bowenur, Mr. Solomon
# 144         1036       1  Lindeberg-Lind, Mr. Erik Gustaf (Mr Edward Lin...
# 158         1050       1                           Borebank, Mr. John James
# 215         1107       1                              Head, Mr. Christopher
# 247         1139       2                             Drew, Mr. James Vivian
# 270         1162       1                       McCaffry, Mr. Thomas Francis
# 327         1219       1        Rosenshine, Mr. George (Mr George Thorne")"
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 11   male  46.0      0      0       694  26.0000   NaN        S
# 128  male  42.0      0      0    211535  13.0000   NaN        S
# 144  male  42.0      0      0     17475  26.5500   NaN        S
# ...

# %%
df[~df.Age.isin([42,46])]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df[(df.Age>40) & (df.Sex =='male')]
# Out:
#      PassengerId  Pclass                                               Name  \
# 2            894       2                          Myles, Mr. Thomas Francis
# 11           903       1                         Jones, Mr. Charles Cresson
# 13           905       2                               Howard, Mr. Benjamin
# 20           912       1                             Rothschild, Mr. Martin
# 25           917       3                            Robins, Mr. Alexander A
# 28           920       1                            Brady, Mr. John Bertram
# 30           922       2                       Louch, Mr. Charles Alexander
# 42           934       3                              Goldsmith, Mr. Nathan
# 46           938       1                           Chevre, Mr. Paul Romaine
# 67           959       1                     Moore, Mr. Clarence Bloomfield
# 81           973       1                                 Straus, Mr. Isidor
# ...

# %%
df.query('Sex=="male" and Age>40')
# Out:
#      PassengerId  Pclass                                               Name  \
# 2            894       2                          Myles, Mr. Thomas Francis
# 11           903       1                         Jones, Mr. Charles Cresson
# 13           905       2                               Howard, Mr. Benjamin
# 20           912       1                             Rothschild, Mr. Martin
# 25           917       3                            Robins, Mr. Alexander A
# 28           920       1                            Brady, Mr. John Bertram
# 30           922       2                       Louch, Mr. Charles Alexander
# 42           934       3                              Goldsmith, Mr. Nathan
# 46           938       1                           Chevre, Mr. Paul Romaine
# 67           959       1                     Moore, Mr. Clarence Bloomfield
# 81           973       1                                 Straus, Mr. Isidor
# ...

# %%
df.sort_values(by='Age',ascending=False)
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
df.sort_values(by='Age',ascending=False).head()
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 96   female  76.0      1      0     19877   78.8500      C46        S
# 81     male  67.0      1      0  PC 17483  221.7792  C55 C57        S
# 236    male  64.0      1      0    110813   75.2500      D37        C
# 305  female  64.0      1      1    112901   26.5500      B26        S
# 179  female  64.0      0      2  PC 17756   83.1583      E45        C

# %%
df.nlargest(3,'Age')
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
#
#         Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 96   female  76.0      1      0     19877   78.8500      C46        S
# 81     male  67.0      1      0  PC 17483  221.7792  C55 C57        S
# 179  female  64.0      0      2  PC 17756   83.1583      E45        C

# %%
df.nlargest(3,'Fare')
# Out:
#      PassengerId  Pclass                                               Name  \
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 53           945       1                         Fortune, Miss. Ethel Flora
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 343  female  58.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 53   female  28.0      3      2     19950  263.0000  C23 C25 C27        S
# 69   female  60.0      1      4     19950  263.0000  C23 C25 C27        S

# %%
df.nsmallest(3,'Fare')
# Out:
#      PassengerId  Pclass                                   Name   Sex   Age  \
# 266         1158       1  Chisholm, Mr. Roderick Robert Crispin  male   NaN
# 372         1264       1                Ismay, Mr. Joseph Bruce  male  49.0
# 21           913       3              Olsen, Master. Artur Karl  male   9.0
#
#      SibSp  Parch   Ticket    Fare        Cabin Embarked
# 266      0      0   112051  0.0000          NaN        S
# 372      0      0   112058  0.0000  B52 B54 B56        S
# 21       0      1  C 17368  3.1708          NaN        S

# %%
df.Name
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df.Name.str.lower()
# Out:
# 0                                  kelly, mr. james
# 1                  wilkes, mrs. james (ellen needs)
# 2                         myles, mr. thomas francis
# 3                                  wirz, mr. albert
# 4      hirvonen, mrs. alexander (helga e lindqvist)
#                            ...
# 413                              spector, mr. woolf
# 414                    oliva y ocana, dona. fermina
# 415                    saether, mr. simon sivertsen
# 416                             ware, mr. frederick
# 417                        peter, master. michael j
# Name: Name, Length: 418, dtype: object

# %%
df.Name.str.len()
# Out:
# 0      16
# 1      32
# 2      25
# 3      16
# 4      44
#        ..
# 413    18
# 414    28
# 415    28
# 416    19
# 417    24
# Name: Name, Length: 418, dtype: int64

# %%
df['Length']=df.Name.str.len()

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df.Name.str.contains('Mr\.')
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 413     True
# 414    False
# 415     True
# 416     True
# 417    False
# Name: Name, Length: 418, dtype: bool

# %%
df['Gender']=df.Name.str.contains('Mr\.')

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df["Name1"] = df.Name.str.split(',')

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df[['last','first']] = df.Name.str.split(',',expand=True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
df.to_csv('New_Titanic.csv')

# %%
df1=pd.read_csv('New_Titanic.csv')

# %%
df1
# Out:
#      Unnamed: 0  PassengerId  Pclass  \
# 0             0          892       3
# 1             1          893       3
# 2             2          894       2
# 3             3          895       3
# 4             4          896       3
# ..          ...          ...     ...
# 413         413         1305       3
# 414         414         1306       1
# 415         415         1307       3
# 416         416         1308       3
# 417         417         1309       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
