# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.set_index('Id',inplace = True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.loc[df.SepalLengthCm==7.7]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 118            7.7           3.8            6.7           2.2  Iris-virginica
# 119            7.7           2.6            6.9           2.3  Iris-virginica
# 123            7.7           2.8            6.7           2.0  Iris-virginica
# 136            7.7           3.0            6.1           2.3  Iris-virginica

# %%
df.loc[(df.SepalLengthCm>7.5) & (df.PetalLengthCm>6.7),['Species']]
# Out:
#             Species
# Id
# 119  Iris-virginica

# %%
df.loc[(df.SepalLengthCm>7.5) & (df.PetalLengthCm>6.7)]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 119            7.7           2.6            6.9           2.3  Iris-virginica

# %%
df = pd.read_csv('loandata.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001722    Male     Yes          0      Graduate            No
# 1  LP002502  Female     Yes          2  Not Graduate           NaN
# 2  LP002949  Female      No         3+      Graduate           NaN
# 3  LP002603  Female      No          0      Graduate            No
# 4  LP001644     NaN     Yes          0      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              150             1800.0       135.0             360.0
# 1              210             2917.0        98.0             360.0
# 2              416            41667.0       350.0             180.0
# 3              645             3683.0       113.0             480.0
# 4              674             5296.0       168.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0     Semiurban           Y
# ...

# %%
#### grouping the data by gender wise
df.groupby(by='Gender').mean()
# Out:
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Gender
# Female      4643.473214        1108.008929  126.697248        352.293578
# Male        5446.460123        1742.932352  149.265957        339.665272
#
#         Credit_History
# Gender
# Female        0.831683
# Male          0.847007

# %%
df.groupby(['Loan_Status']).max()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\477364940.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(['Loan_Status']).max()
#               Loan_ID     Education  ApplicantIncome  CoapplicantIncome  \
# Loan_Status
# N            LP002990  Not Graduate            81000            41667.0
# Y            LP002984  Not Graduate            63337            20000.0
#
#              LoanAmount  Loan_Amount_Term  Credit_History Property_Area
# Loan_Status
# N                 570.0             480.0             1.0         Urban
# Y                 700.0             480.0             1.0         Urban

# %%
df.groupby(['Education']).max()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\2840766624.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(['Education']).max()
#                Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Education
# Graduate      LP002990            81000            41667.0       700.0
# Not Graduate  LP002964            18165             7101.0       279.0
#
#               Loan_Amount_Term  Credit_History Property_Area Loan_Status
# Education
# Graduate                 480.0             1.0         Urban           Y
# Not Graduate             480.0             1.0         Urban           Y

# %%
df.groupby(['Married']).max()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\1436759964.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(['Married']).max()
#           Loan_ID     Education  ApplicantIncome  CoapplicantIncome  \
# Married
# No       LP002990  Not Graduate            37719            41667.0
# Yes      LP002984  Not Graduate            81000            20000.0
#
#          LoanAmount  Loan_Amount_Term  Credit_History Property_Area  \
# Married
# No            650.0             480.0             1.0         Urban
# Yes           700.0             480.0             1.0         Urban
#
#         Loan_Status
# Married
# No                Y
# Yes               Y

# %%
df.groupby(['Loan_Status']).max()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\477364940.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(['Loan_Status']).max()
#               Loan_ID     Education  ApplicantIncome  CoapplicantIncome  \
# Loan_Status
# N            LP002990  Not Graduate            81000            41667.0
# Y            LP002984  Not Graduate            63337            20000.0
#
#              LoanAmount  Loan_Amount_Term  Credit_History Property_Area
# Loan_Status
# N                 570.0             480.0             1.0         Urban
# Y                 700.0             480.0             1.0         Urban

# %%
df.groupby(['Education']).max()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\719533210.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   df.groupby(['Education']).max()
#                Loan_ID  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Education
# Graduate      LP002990            81000            41667.0       700.0
# Not Graduate  LP002964            18165             7101.0       279.0
#
#               Loan_Amount_Term  Credit_History Property_Area Loan_Status
# Education
# Graduate                 480.0             1.0         Urban           Y
# Not Graduate             480.0             1.0         Urban           Y

# %%
df.groupby(by='Gender')['ApplicantIncome'].std()
# Out:
# Gender
# Female    3585.381488
# Male      6185.789262
# Name: ApplicantIncome, dtype: float64

# %%
### uniques in Education
df.Education.unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df.Property_Area.unique()
# Out:
# array(['Rural', 'Semiurban', 'Urban'], dtype=object)

# %%
### count of uniques in  the property Area
df.Property_Area.value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
233+202+179
# Out:
# 614

# %%
### Education-> appIncome, Term mean()
df.groupby(by = 'Education')['ApplicantIncome','Loan_Amount_Term'].mean()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\62411222.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by = 'Education')['ApplicantIncome','Loan_Amount_Term'].mean()
#               ApplicantIncome  Loan_Amount_Term
# Education
# Graduate          5857.433333        344.669492
# Not Graduate      3777.283582        332.156250

# %%
### Gender  --> AppIncome, LoanAmount Mean()
df.groupby(by = 'Gender')['ApplicantIncome','LoanAmount','Credit_History'].mean()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\2348560943.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by = 'Gender')['ApplicantIncome','LoanAmount','Credit_History'].mean()
#         ApplicantIncome  LoanAmount  Credit_History
# Gender
# Female      4643.473214  126.697248        0.831683
# Male        5446.460123  149.265957        0.847007

# %%
### Gender  --> AppIncome, LoanAmount,Credit History  Mean()
df.groupby(by = 'Gender')['ApplicantIncome','LoanAmount'].mean()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\1995282856.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by = 'Gender')['ApplicantIncome','LoanAmount'].mean()
#         ApplicantIncome  LoanAmount
# Gender
# Female      4643.473214  126.697248
# Male        5446.460123  149.265957

# %%
df.groupby(by = ['Gender','Married'])['ApplicantIncome','LoanAmount'].mean()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\3361445419.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by = ['Gender','Married'])['ApplicantIncome','LoanAmount'].mean()
#                 ApplicantIncome  LoanAmount
# Gender Married
# Female No           4503.787500  116.115385
#        Yes          4829.645161  153.322581
# Male   No           5236.146154  136.088000
#        Yes          5529.540616  154.011662

# %%
df.groupby(by = ['Married','Gender'])['ApplicantIncome','LoanAmount'].mean()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\3284599892.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(by = ['Married','Gender'])['ApplicantIncome','LoanAmount'].mean()
#                 ApplicantIncome  LoanAmount
# Married Gender
# No      Female      4503.787500  116.115385
#         Male        5236.146154  136.088000
# Yes     Female      4829.645161  153.322581
#         Male        5529.540616  154.011662

# %%
df.groupby(['Education','Self_Employed','Married'])['Credit_History']

# %%
list(df.groupby(['Education','Self_Employed','Married'])['Credit_History'])
# Out:
# [(('Graduate', 'No', 'No'),
#   3      1.0
#   11     0.0
#   18     1.0
#   21     1.0
#   26     1.0
#         ...
#   577    1.0
#   580    1.0
#   587    0.0
#   603    1.0
#   608    1.0
#   Name: Credit_History, Length: 136, dtype: float64),
#  (('Graduate', 'No', 'Yes'),
#   0      1.0
#   6      1.0
#   7      NaN
#   8      1.0
#   9      1.0
#         ...
#   606    1.0
#   607    1.0
#   610    0.0
#   611    1.0
#   613    0.0
#   Name: Credit_History, Length: 250, dtype: float64),
#  (('Graduate', 'Yes', 'No'),
#   106    NaN
#   120    1.0
#   255    NaN
#   384    0.0
#   396    1.0
#   427    1.0
#   479    1.0
#   498    1.0
#   508    1.0
#   510    1.0
#   511    1.0
#   514    1.0
#   519    1.0
#   520    1.0
#   540    1.0
#   551    1.0
#   565    0.0
#   569    1.0
#   589    1.0
#   591    0.0
#   602    NaN
#   Name: Credit_History, dtype: float64),
#  (('Graduate', 'Yes', 'Yes'),
#   4      1.0
#   5      1.0
#   13     1.0
#   48     NaN
#   57     0.0
# ...

# %%
df.groupby(['Education','Self_Employed','Married']).sum()
# Out:
#                                     ApplicantIncome  CoapplicantIncome  \
# Education    Self_Employed Married
# Graduate     No            No                650833      190086.000000
#                            Yes              1471681      453478.919989
#              Yes           No                169942        6050.000000
#                            Yes               332866      101699.000000
# Not Graduate No            No                119806       25905.000000
#                            Yes               263933      120271.000000
#              Yes           No                 54500        6135.000000
#                            Yes                47919        9226.000000
#
#                                     LoanAmount  Loan_Amount_Term  \
# Education    Self_Employed Married
# Graduate     No            No          16964.0           48036.0
#                            Yes         39018.0           83664.0
# ...

# %%
df.groupby(['Education','Married','Self_Employed'])['Credit_History','Loan_Status'].count()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_21120\2194266975.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['Education','Married','Self_Employed'])['Credit_History','Loan_Status'].count()
#                                     Credit_History  Loan_Status
# Education    Married Self_Employed
# Graduate     No      No                        130          136
#                      Yes                        18           21
#              Yes     No                        230          250
#                      Yes                        42           44
# Not Graduate No      No                         33           35
#                      Yes                         6            7
#              Yes     No                         67           76
#                      Yes                         9           10

# %%
df['Gender'].isnull().sum()
# Out:
# 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.groupby(['Gender','Married'])['Gender'].agg(['count'])
# Out:
#                 count
# Gender Married
# Female No          80
#        Yes         31
# Male   No         130
#        Yes        357

# %%
df.groupby(['Gender'])['LoanAmount'].agg(['count'])
# Out:
#         count
# Gender
# Female    109
# Male      470

# %%
df.groupby(['Gender'])['LoanAmount'].agg(['mean'])
# Out:
#               mean
# Gender
# Female  126.697248
# Male    149.265957

# %%
df.groupby(['Gender'])['LoanAmount'].agg(['sum'])
# Out:
#             sum
# Gender
# Female  13810.0
# Male    70155.0

# %%
df.groupby(['Gender'])['LoanAmount'].agg(['mean','sum','count'])
# Out:
#               mean      sum  count
# Gender
# Female  126.697248  13810.0    109
# Male    149.265957  70155.0    470

# %%
df.groupby(['Gender'])['LoanAmount'].agg([np.mean,np.std,np.min,np.max])
# Out:
#               mean        std  amin   amax
# Gender
# Female  126.697248  79.286460   9.0  600.0
# Male    149.265957  82.810851  17.0  650.0

# %%
df1 = df.groupby(['Married','Gender'])

# %%
df1

# %%
list(df1)
# Out:
# [(('No', 'Female'),
#         Loan_ID  Gender Married Dependents     Education Self_Employed  \
#   2    LP002949  Female      No         3+      Graduate           NaN
#   3    LP002603  Female      No          0      Graduate            No
#   11   LP002287  Female      No          0      Graduate            No
#   21   LP001917  Female      No          0      Graduate            No
#   25   LP002113  Female      No         3+  Not Graduate            No
#   ..        ...     ...     ...        ...           ...           ...
#   564  LP001422  Female      No          0      Graduate            No
#   580  LP002634  Female      No          1      Graduate            No
#   589  LP002194  Female      No          0      Graduate           Yes
#   596  LP002582  Female      No          0  Not Graduate           Yes
#   598  LP002731  Female      No          0  Not Graduate           Yes
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df1['ApplicantIncome'].mean()
# Out:
# Married  Gender
# No       Female    4503.787500
#          Male      5236.146154
# Yes      Female    4829.645161
#          Male      5529.540616
# Name: ApplicantIncome, dtype: float64

# %%
df1['ApplicantIncome'].mean().sort_values()
# Out:
# Married  Gender
# No       Female    4503.787500
# Yes      Female    4829.645161
# No       Male      5236.146154
# Yes      Male      5529.540616
# Name: ApplicantIncome, dtype: float64

# %%
df1['ApplicantIncome'].mean().sort_values(ascending=True)
# Out:
# Married  Gender
# No       Female    4503.787500
# Yes      Female    4829.645161
# No       Male      5236.146154
# Yes      Male      5529.540616
# Name: ApplicantIncome, dtype: float64

# %%
df1['ApplicantIncome'].mean().sort_values(ascending=False)
# Out:
# Married  Gender
# Yes      Male      5529.540616
# No       Male      5236.146154
# Yes      Female    4829.645161
# No       Female    4503.787500
# Name: ApplicantIncome, dtype: float64
